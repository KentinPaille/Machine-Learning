# %% [markdown]
# **Classification**

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# **Load Data**

# %%
X_train = np.load("../data/classification/X_train.npy")
X_test = np.load("../data/classification/X_test.npy")
y_train = np.load("../data/classification/y_train.npy")
y_test = np.load("../data/classification/y_test.npy")

print(f"Train set: {X_train.shape}, Test set: {X_test.shape}")
# Out:
# Train set: (500, 50), Test set: (500, 50)

# %% [markdown]
# **Model 1 : Logistic Regression**

# %%
log_reg = LogisticRegression(max_iter=5000, solver="lbfgs")
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %% [markdown]
# **Model 2 : Neural Network (TensorFlow / Keras)**

# %%
# Split training into (train/val)
X_tr, X_val, y_tr, y_val = train_test_split(
    X_train, y_train, test_size=0.2, stratify=y_train, random_state=42
)

# Define a simple MLP
model = Sequential([
    Dense(128, activation="relu", input_shape=(X_tr.shape[1],)),
    Dense(64, activation="relu"),
    Dense(1, activation="tanh")
])

# Compile with Adam optimizer
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="hinge",
    metrics=["accuracy"]
)

# Train on train/val only
history = model.fit(
    X_tr, y_tr,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/100
# C:\Users\kenti\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1164 - loss: 0.8621 - val_accuracy: 0.3100 - val_loss: 0.5897
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3559 - loss: 0.4230 - val_accuracy: 0.3500 - val_loss: 0.5538
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4118 - loss: 0.3436 - val_accuracy: 0.3200 - val_loss: 0.5434
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4319 - loss: 0.2360 - val_accuracy: 0.3200 - val_loss: 0.5372
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4083 - loss: 0.2465 - val_accuracy: 0.3300 - val_loss: 0.5295
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4197 - loss: 0.2582 - val_accuracy: 0.3200 - val_loss: 0.5147
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4517 - loss: 0.1828 - val_accuracy: 0.3000 - val_loss: 0.5021
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4110 - loss: 0.2081 - val_accuracy: 0.3200 - val_loss: 0.4867
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3993 - loss: 0.2155 - val_accuracy: 0.3200 - val_loss: 0.4826
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4016 - loss: 0.1949 - val_accuracy: 0.3300 - val_loss: 0.4829
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4173 - loss: 0.1931 - val_accuracy: 0.3300 - val_loss: 0.4794
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4374 - loss: 0.1723 - val_accuracy: 0.3400 - val_loss: 0.4746
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4219 - loss: 0.1538 - val_accuracy: 0.3400 - val_loss: 0.4778
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4531 - loss: 0.1406 - val_accuracy: 0.3300 - val_loss: 0.4756
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4159 - loss: 0.1536 - val_accuracy: 0.3400 - val_loss: 0.4610
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4292 - loss: 0.1421 - val_accuracy: 0.3400 - val_loss: 0.4539
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4156 - loss: 0.1306 - val_accuracy: 0.3400 - val_loss: 0.4522
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4022 - loss: 0.1357 - val_accuracy: 0.3500 - val_loss: 0.4305
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4560 - loss: 0.1468 - val_accuracy: 0.3500 - val_loss: 0.4358
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4260 - loss: 0.1391 - val_accuracy: 0.3600 - val_loss: 0.4235
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4414 - loss: 0.1130 - val_accuracy: 0.3400 - val_loss: 0.4295
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4572 - loss: 0.1189 - val_accuracy: 0.3500 - val_loss: 0.4290
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4433 - loss: 0.0954 - val_accuracy: 0.3500 - val_loss: 0.4178
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4449 - loss: 0.1052 - val_accuracy: 0.3400 - val_loss: 0.4215
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4632 - loss: 0.1002 - val_accuracy: 0.3400 - val_loss: 0.4241
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4119 - loss: 0.0901 - val_accuracy: 0.3400 - val_loss: 0.4265
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4385 - loss: 0.0790 - val_accuracy: 0.3400 - val_loss: 0.4256
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4491 - loss: 0.1000 - val_accuracy: 0.3400 - val_loss: 0.4309
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4594 - loss: 0.1096 - val_accuracy: 0.3400 - val_loss: 0.4330
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4317 - loss: 0.0971 - val_accuracy: 0.3400 - val_loss: 0.4331
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4448 - loss: 0.0895 - val_accuracy: 0.3400 - val_loss: 0.4305
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4334 - loss: 0.1326 - val_accuracy: 0.3400 - val_loss: 0.4283
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4434 - loss: 0.0999 - val_accuracy: 0.3400 - val_loss: 0.4281
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4721 - loss: 0.0933 - val_accuracy: 0.3400 - val_loss: 0.4284
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4624 - loss: 0.1078 - val_accuracy: 0.3400 - val_loss: 0.4287
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4485 - loss: 0.0855 - val_accuracy: 0.3400 - val_loss: 0.4281
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4571 - loss: 0.0848 - val_accuracy: 0.3400 - val_loss: 0.4272
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4634 - loss: 0.0963 - val_accuracy: 0.3400 - val_loss: 0.4246
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4485 - loss: 0.0895 - val_accuracy: 0.3400 - val_loss: 0.4204
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4828 - loss: 0.0801 - val_accuracy: 0.3700 - val_loss: 0.4055
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4576 - loss: 0.0942 - val_accuracy: 0.3700 - val_loss: 0.4061
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4610 - loss: 0.0855 - val_accuracy: 0.3600 - val_loss: 0.4089
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4537 - loss: 0.0994 - val_accuracy: 0.3600 - val_loss: 0.4114
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4698 - loss: 0.0938 - val_accuracy: 0.3500 - val_loss: 0.4122
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4868 - loss: 0.1006 - val_accuracy: 0.3500 - val_loss: 0.4118
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4299 - loss: 0.0942 - val_accuracy: 0.3500 - val_loss: 0.4118
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4513 - loss: 0.0700 - val_accuracy: 0.3500 - val_loss: 0.4120
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4530 - loss: 0.0861 - val_accuracy: 0.3500 - val_loss: 0.4109
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4939 - loss: 0.0758 - val_accuracy: 0.3500 - val_loss: 0.4105
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4635 - loss: 0.0912 - val_accuracy: 0.3500 - val_loss: 0.4107
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4697 - loss: 0.0780 - val_accuracy: 0.3500 - val_loss: 0.4103
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4181 - loss: 0.0985 - val_accuracy: 0.3500 - val_loss: 0.4105
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4683 - loss: 0.0864 - val_accuracy: 0.3500 - val_loss: 0.4105
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4510 - loss: 0.0756 - val_accuracy: 0.3500 - val_loss: 0.4105
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4233 - loss: 0.1314 - val_accuracy: 0.3500 - val_loss: 0.4104
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4571 - loss: 0.1106 - val_accuracy: 0.3500 - val_loss: 0.4104
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4404 - loss: 0.1086 - val_accuracy: 0.3500 - val_loss: 0.4102
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4799 - loss: 0.0757 - val_accuracy: 0.3500 - val_loss: 0.4103
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4491 - loss: 0.1281 - val_accuracy: 0.3500 - val_loss: 0.4102
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5047 - loss: 0.0955 - val_accuracy: 0.3500 - val_loss: 0.4101
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4413 - loss: 0.0779 - val_accuracy: 0.3500 - val_loss: 0.4102
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4531 - loss: 0.0873 - val_accuracy: 0.3500 - val_loss: 0.4102
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4774 - loss: 0.0779 - val_accuracy: 0.3500 - val_loss: 0.4100
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4661 - loss: 0.0927 - val_accuracy: 0.3500 - val_loss: 0.4099
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4425 - loss: 0.0984 - val_accuracy: 0.3500 - val_loss: 0.4098
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4467 - loss: 0.0793 - val_accuracy: 0.3500 - val_loss: 0.4098
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4645 - loss: 0.0901 - val_accuracy: 0.3500 - val_loss: 0.4098
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4483 - loss: 0.0881 - val_accuracy: 0.3500 - val_loss: 0.4096
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4433 - loss: 0.0953 - val_accuracy: 0.3700 - val_loss: 0.4094
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4443 - loss: 0.0994 - val_accuracy: 0.3700 - val_loss: 0.4093
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4592 - loss: 0.1003 - val_accuracy: 0.3700 - val_loss: 0.4088

# %% [markdown]
# **Final Evaluation (TEST set ONCE)**

# %%
# Logistic Regression
y_pred_lr = log_reg.predict(X_test)
acc_lr = accuracy_score(y_test, y_pred_lr)

# Neural Net
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)

print("\n---- Final Results ----\n")
print(f"Logistic Regression Test Accuracy: {acc_lr:.4f}")
print(f"Neural Network (Keras) Test Accuracy: {test_acc:.4f}")
# Out:
# ---- Final Results ----
#
# Logistic Regression Test Accuracy: 0.8360
# Neural Network (Keras) Test Accuracy: 0.3480
